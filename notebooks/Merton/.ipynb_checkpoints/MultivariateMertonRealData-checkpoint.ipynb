# %%
import os
import sys
import numpy as np
from datetime import datetime
from deep_fields import data_path
from matplotlib import pyplot as plt

from deep_fields.data.crypto.dataloaders import CryptoDataLoader
from deep_fields.models.random_fields.mcmc_preprocessing import estimate_mcmc_dataloader_and_parameters_mertonjump
from deep_fields.models.random_fields.mcmc_preprocessing import preprocess_cryptoportfolio_for_mertonjump
from deep_fields.models.random_fields.poisson_covariance import MertonJumpsPoissonCovariance

# %%
date_string = "2021-06-14"
crypto_folder = os.path.join(data_path, "raw", "crypto")
data_folder = os.path.join(crypto_folder,date_string)

kwargs = {"path_to_data": data_folder,
          "date_string":date_string,
          "batch_size": 29,
          "steps_ahead": 10,
          "span": "full"}

crypto_data_loader = CryptoDataLoader('cpu', **kwargs)
data_batch = next(crypto_data_loader.train.__iter__())

# defines portfolio to study
date0 = datetime(2018, 1, 1)
datef = datetime(2019, 1, 1)
crypto_data_loader.set_portfolio_assets("2021-06-14",
                                        "full",
                                        predictor=None,
                                        top=4,
                                        date0=date0,
                                        datef=datef,
                                        max_size=4)
# Out:
# Current Coin 1 ethereum
# Current Coin 2 tether
# Current Coin 3 binancecoin
# Current Coin 4 cardano

# %%
corrected_prices_data = preprocess_cryptoportfolio_for_mertonjump(crypto_data_loader)
model_param,data_loader = estimate_mcmc_dataloader_and_parameters_mertonjump(corrected_prices_data)
# Out:
# Sigma
# tensor(0.0060)

# %%
inference_param = MertonJumpsPoissonCovariance.get_inference_parameters()
inference_param.update({"train_jumps_intensity": True})
inference_param.update({"train_jumps_arrival": True})
inference_param.update({"train_jumps_size": True})
inference_param.update({"train_expected_returns": True})
inference_param.update({"train_diffusion_covariance": True})
inference_param["train_jumps_mean"] = True
inference_param["train_jumps_covariance"] = True
inference_param.update({"nmc": 1000,
                        "burning": 500,
                        "metrics_logs": 50})

mjpc = MertonJumpsPoissonCovariance(None, data_loader, None, **model_param)
monte_carlo_parameters = mjpc.inference(data_loader, **inference_param)
# Out:
#   0%|                                                                                         | 0/1000 [00:00<?, ?it/s]
# New Model Set For Inference
# Data Loader has No Parameters
# #      ----------------
# #      Start of MCMC
# #      ----------------
# Monte Carlo 0
#   0%|▏                                                                                | 2/1000 [00:00<03:33,  4.67it/s]
# Monte Carlo 1
#   0%|▏                                                                                | 3/1000 [00:00<03:28,  4.78it/s]
# Monte Carlo 2
#   0%|▎                                                                                | 4/1000 [00:00<03:12,  5.18it/s]
# Monte Carlo 3
# Monte Carlo 4
#   1%|▍                                                                                | 6/1000 [00:01<03:25,  4.83it/s]
# Monte Carlo 5
#   1%|▌                                                                                | 7/1000 [00:01<03:14,  5.11it/s]
# Monte Carlo 6
# Monte Carlo 7
# ...

# %%
burning = inference_param.get("burning")
burning
# Out:
# 500

# %% [markdown]
# # COVARIANCE MATRIX

# %%
np.stack(monte_carlo_parameters['diffusion_covariance'])[burning:,:].mean(axis=0)
# Out:
# array([[0.00185943, 0.00131885, 0.0015847 , 0.00146305, 0.00149979],
#        [0.00131885, 0.00183083, 0.00156044, 0.00152891, 0.00117844],
#        [0.0015847 , 0.00156044, 0.0017259 , 0.00145232, 0.00135023],
#        [0.00146305, 0.00152891, 0.00145232, 0.08950032, 0.00115187],
#        [0.00149979, 0.00117844, 0.00135023, 0.00115187, 0.0019885 ]])

# %%
np.stack(monte_carlo_parameters['expected_returns'])[burning:,:].mean(axis=0)
# Out:
# array([0.0017586 , 0.00283002, 0.00011221, 0.01484641, 0.00526532])

# %%
plt.plot(np.stack(monte_carlo_parameters['expected_returns'])[burning:,0])

# %%
arrivals_indicator = np.vstack(monte_carlo_parameters['arrivals_indicator'])[burning:,:].sum(axis=1).mean()
arrivals_indicator
# Out:
# 0.0

# %%
arrivals_intensity_stats = monte_carlo_parameters["arrivals_intensity"]
arrivals_intensity_mean = np.asarray(arrivals_intensity_stats).mean()
arrivals_intensity_std = np.asarray(arrivals_intensity_stats).std()

# %%
arrivals_intensity_mean
# Out:
# 0.0023243106248569847
